# %% [markdown]
# <a href="https://colab.research.google.com/github/thaheshan/Breast_Cancer_Prediction_Model/blob/main/Notebook01ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Author: Suresh Thaheshan
# Peer Reviewer: [Ayman Jaleel]
# Review Date: [Date]


#importing pandas library for the claculatiions for the dataset k-nearest prediction practicals
#or understanding the concept of k-nearest concept
#we use pandas library for Data Analysis And Data Manipulation.
#which is most widely used in tech industry.


#%% 🔧 Import Required Libraries
import pandas as pd
import numpy as np
import os

save_path = '/content/drive/MyDrive/Machine_Learning_CourseWork'


os.makedirs(save_path, exist_ok=True)

# %%
#Read in the data using pandas
#using a variable called as df to read the datapath file, which has excel sheet table with the dataset
#using the pandas library retrive the dataset to the system , through the excel sheet root path.
df = pd.read_csv('/content/drive/MyDrive/Machine_Learning_CourseWork/5DATA002W.2 Coursework Dataset(25012025v6.0) (2).csv')

# %%
#Check a sample of the dataset
#the .head element will manually read sample data of 5 rows and , it will give sample data
df.head()
# Out:
#   Patient_ID  Month_of_Birth   Age     Sex   Occupation T_Stage N_Stage  \
# 0      A0012              12  68.0  Female     Teaching      T1      N1
# 1      A0013              12  50.0  Female      Medical      T2      N2
# 2      A0014              11  58.0  Female  Engineering      T3      N3
# 3      A0015               3  58.0  Female   Technology      T1      N1
# 4      A0016               1  47.0  Female   Multimedia      T2      N1
#
#   6th_Stage             Differentiated  Grade   A_Stage  Tumor_Size  \
# 0       IIA      Poorly differentiated      3  Regional         4.0
# 1      IIIA  Moderately differentiated      2  Regional        35.0
# 2      IIIC  Moderately differentiated      2  Regional        63.0
# 3       IIA      Poorly differentiated      3  Regional        18.0
# 4       IIB      Poorly differentiated      3  Regional        41.0
#
#   Estrogen_Status Progesterone_Status  Regional_Node_Examined  \
# ...

# %%
# Check dataset shape
print("\nDataset Shape:", df.shape)



# Get basic statistics
print("\nData Statistics:")
print(df.describe())
# Out:
# Dataset Shape: (4024, 18)
#
# Data Statistics:
#        Month_of_Birth          Age        Grade   Tumor_Size  \
# count     4024.000000  4015.000000  4024.000000  4021.000000
# mean         6.481362    54.107098     2.150596    30.419299
# std          3.475442    11.715528     0.638234    21.161080
# min          1.000000   -50.000000     1.000000   -75.000000
# 25%          3.000000    47.000000     2.000000    16.000000
# 50%          6.000000    54.000000     2.000000    25.000000
# 75%         10.000000    61.000000     3.000000    38.000000
# max         12.000000   502.000000     4.000000   140.000000
#
#        Regional_Node_Examined  Reginol_Node_Positive  Survival_Months
# count             4023.000000            4024.000000      4024.000000
# mean                14.373602               4.158052        71.472167
# std                  8.129293               5.109331        25.361855
# min                  1.000000               1.000000         1.000000
# ...

# %%
# Check for missing values in the dataset
df.isnull().sum()
# Out:
# Patient_ID                   0
# Month_of_Birth               0
# Age                          9
# Sex                          4
# Occupation                3981
# T_Stage                      0
# N_Stage                      0
# 6th_Stage                    0
# Differentiated               0
# Grade                        0
# A_Stage                      0
# Tumor_Size                   3
# Estrogen_Status              0
# Progesterone_Status          0
# Regional_Node_Examined       1
# Reginol_Node_Positive        0
# Survival_Months              0
# Mortality_Status             0
# dtype: int64

# %%
#%% Initial Data Exploration (Reused from Seminar 3)
# Display first 5 rows
print("Initial Data Preview:")
print(df.head())







#%% Handle Missing Values (Reused from Seminar 4)
# Check for missing values
print("\nMissing Values Before Handling:")
print(df.isnull().sum())



# Fill missing Age with median
df['Age'].fillna(df['Age'].median(), inplace=True)



# Drop rows with missing Tumor_Size
df = df.dropna(subset=['Tumor_Size'])

# Verify missing values handled
print("\nMissing Values After Handling:")
print(df.isnull().sum())



#%% Handle Invalid Values (Reused from Seminar 5)
# Fix negative age
df['Age'] = df['Age'].abs()



# Fix negative tumor size
df['Tumor_Size'] = df['Tumor_Size'].abs()

# Remove unrealistic ages (>100)
df = df[df['Age'] <= 100]



#%% Feature Engineering (Reused from Seminar 6)
# Create Age Groups
df['Age_Group'] = pd.cut(df['Age'],
                         bins=[0, 40, 60, 100],
                         labels=['Young', 'Middle', 'Senior'])


#  Reused from Code Reuse Session 1 (Week 5) - Page 2
#  Reused from Seminar 6 - Age Group Creation
# ➤Custom logic approved by [Tutor Name] in Peer Review 1


# One-hot encode categorical features
cat_cols = ['Sex', 'T_Stage', 'N_Stage', '6th_Stage', 'Differentiated', 'A_Stage']
df_encoded = pd.get_dummies(df, columns=cat_cols, drop_first=True)


#%% Create Classification Dataset (Reused from Code Reuse Session 1)
# Classification dataset for mortality prediction
classification_df = df_encoded.copy()


# Drop irrelevant columns
classification_df = classification_df.drop(['Survival_Months', 'Patient_ID'], axis=1)


# Convert target to binary
classification_df['Mortality_Status'] = classification_df['Mortality_Status'].map({'Alive':0, 'Dead':1})



#%% Create Regression Dataset (Reused from Code Reuse Session 1)
# Regression dataset for survival months prediction
regression_df = df_encoded.copy()


# Drop irrelevant columns
regression_df = regression_df.drop(['Mortality_Status', 'Patient_ID'], axis=1)




#%% Save Processed Datasets (Reused from Seminar 8)
# Save classification datas
classification_df.to_csv(os.path.join(save_path, 'classification_dataset3.csv'), index=False)



# Save regression dataset
regression_df.to_csv('regression_dataset.csv', index=False)


print("\nPreprocessing completed. Datasets saved.")
# Out:
# Initial Data Preview:
#   Patient_ID  Month_of_Birth   Age     Sex   Occupation T_Stage N_Stage  \
# 0      A0012              12  68.0  Female     Teaching      T1      N1
# 1      A0013              12  50.0  Female      Medical      T2      N2
# 2      A0014              11  58.0  Female  Engineering      T3      N3
# 3      A0015               3  58.0  Female   Technology      T1      N1
# 4      A0016               1  47.0  Female   Multimedia      T2      N1
#
#   6th_Stage             Differentiated  Grade   A_Stage  Tumor_Size  \
# 0       IIA      Poorly differentiated      3  Regional         4.0
# 1      IIIA  Moderately differentiated      2  Regional        35.0
# 2      IIIC  Moderately differentiated      2  Regional        63.0
# 3       IIA      Poorly differentiated      3  Regional        18.0
# 4       IIB      Poorly differentiated      3  Regional        41.0
#
#   Estrogen_Status Progesterone_Status  Regional_Node_Examined  \
# ...
